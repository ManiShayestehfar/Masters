# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
import time
import pickle
import sympy as sp

from activation_funcs import *

# from a_5_utils import *
from a_5_utils_a_4_induced import *

# %%
# grid_interaction_graph([1,2,3,4,5],[RELU, TANH, SIGMOID], tol=1e-13)
grid_interaction_graph([RELU, TANH, SIGMOID], tol=1e-13)

# %%
def A4_subgroup_stab_of_4():
    """A4 as the stabiliser of point 4 inside A5."""
    G = A5_elements()
    H = [g for g in G if g[4] == 4]
    if len(H) != 12:
        raise RuntimeError(f"Expected |A4|=12, got {len(H)}. Something is off.")
    return H

A4_subgroup_stab_of_4()
# Out:
# [(0, 1, 2, 3, 4),
#  (0, 2, 3, 1, 4),
#  (0, 3, 1, 2, 4),
#  (1, 0, 3, 2, 4),
#  (1, 2, 0, 3, 4),
#  (1, 3, 2, 0, 4),
#  (2, 0, 1, 3, 4),
#  (2, 1, 3, 0, 4),
#  (2, 3, 0, 1, 4),
#  (3, 0, 2, 1, 4),
#  (3, 1, 0, 2, 4),
#  (3, 2, 1, 0, 4)]
